# %%
#| hide
from chat.core import *

# %% [markdown]
# # chat
#
# > Chat app

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install chat in Development mode

# %% [markdown]
# ```sh
# # make sure chat package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to chat
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/northarray/chat.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c northarray chat
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install chat
# ```
#
#
# [repo]: https://github.com/northarray/chat
# [docs]: https://northarray.github.io/chat/
# [pypi]: https://pypi.org/project/chat/
# [conda]: https://anaconda.org/northarray/chat

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/northarray/chat
# [docs]: https://northarray.github.io/chat/
# [pypi]: https://pypi.org/project/chat/
# [conda]: https://anaconda.org/northarray/chat

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
